# %% [markdown]
# ![image not found](https://www.microcapobserver.com/root_upld/general-news/2021/04/73824/org_99079202104091720.jpg)

# %%
#ignore the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Preparation and Cleaning

# %%
import os
os.chdir('C:\\Users\\maina\\Downloads\\ipl')
os.getcwd()
# Out:
# 'C:\\Users\\maina\\Downloads\\ipl'

# %%
#import libraies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv('IPL_Matches.csv')
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.date
# Out:
# 0      2008-04-18
# 1      2008-04-19
# 2      2008-04-19
# 3      2008-04-20
# 4      2008-04-20
#           ...
# 811    2020-09-28
# 812    2020-11-05
# 813    2020-11-06
# 814    2020-11-08
# 815    2020-11-10
# Name: date, Length: 816, dtype: object

# %%
df['date'] = pd.to_datetime(df.date)
df['year'] = pd.DatetimeIndex(df.date).year

# %%
df['month'] = pd.DatetimeIndex(df.date).month
df['day'] = pd.DatetimeIndex(df.date).day
df['weekday'] = pd.DatetimeIndex(df.date).weekday

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# year                 0
# month                0
# day                  0
# weekday              0
# dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah'], dtype=object)

# %%
df.loc[df['city'].isnull()]
# Out:
#          id city       date player_of_match  \
# 399  729281  NaN 2014-04-17       YS Chahal
# 402  729287  NaN 2014-04-19        PA Patel
# 403  729289  NaN 2014-04-19       JP Duminy
# 404  729291  NaN 2014-04-20      GJ Maxwell
# 406  729295  NaN 2014-04-22      GJ Maxwell
# 407  729297  NaN 2014-04-23       RA Jadeja
# 408  729299  NaN 2014-04-24         CA Lynn
# 409  729301  NaN 2014-04-25        AJ Finch
# 410  729303  NaN 2014-04-25       MM Sharma
# 413  729309  NaN 2014-04-27         M Vijay
# 414  729311  NaN 2014-04-27        DR Smith
# 415  729313  NaN 2014-04-28  Sandeep Sharma
# 417  729317  NaN 2014-04-30         B Kumar
#
#                                    venue  neutral_venue  \
# 399              Sharjah Cricket Stadium              1
# 402  Dubai International Cricket Stadium              1
# 403  Dubai International Cricket Stadium              1
# 404              Sharjah Cricket Stadium              1
# 406              Sharjah Cricket Stadium              1
# ...

# %%
# df.loc[df['venue'] == 'Dubai International Cricket Stadium','city']

# %%
#since there are missing value from Dubai and middle east venues, so we try to replace those city as their city names
df['city'].fillna('Dubai', inplace = True)

# %%
df['city'].isna().sum()
# Out:
# 0

# %%
df[df['player_of_match'].isnull()]
# Out:
#           id       city       date player_of_match                  venue  \
# 241   501265      Delhi 2011-05-21             NaN       Feroz Shah Kotla
# 486   829763  Bangalore 2015-04-29             NaN  M Chinnaswamy Stadium
# 511   829813  Bangalore 2015-05-17             NaN  M Chinnaswamy Stadium
# 744  1178424  Bengaluru 2019-04-30             NaN  M.Chinnaswamy Stadium
#
#      neutral_venue                        team1             team2  \
# 241              0             Delhi Daredevils     Pune Warriors
# 486              0  Royal Challengers Bangalore  Rajasthan Royals
# 511              0  Royal Challengers Bangalore  Delhi Daredevils
# 744              0  Royal Challengers Bangalore  Rajasthan Royals
#
#                      toss_winner toss_decision  ... result result_margin  \
# 241             Delhi Daredevils           bat  ...    NaN           NaN
# 486             Rajasthan Royals         field  ...    NaN           NaN
# ...

# %%
df.drop([241,486,511,744], inplace=True)

# %%
#df.info()
df.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# year               0
# month              0
# day                0
# weekday            0
# dtype: int64

# %%
df[df.result_margin.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, city, date, player_of_match, venue, neutral_venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, eliminator, method, umpire1, umpire2, year, month, day, weekday]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['result_margin'].fillna(0, inplace = True)

# %%
df.method.unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df['method'].fillna('regular', inplace = True)

# %% [markdown]
# #### Now we will try to load the `ball by ball` dataset

# %%
df1 = pd.read_csv('IPL-Ball-by-Ball.csv')
df1
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
df1.shape
# Out:
# (193468, 18)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   inning            193468 non-null  int64
#  2   over              193468 non-null  int64
#  3   ball              193468 non-null  int64
#  4   batsman           193468 non-null  object
#  5   non_striker       193468 non-null  object
#  6   bowler            193468 non-null  object
#  7   batsman_runs      193468 non-null  int64
#  8   extra_runs        193468 non-null  int64
#  9   total_runs        193468 non-null  int64
#  10  non_boundary      193468 non-null  int64
#  11  is_wicket         193468 non-null  int64
#  12  dismissal_kind    9495 non-null    object
#  13  player_dismissed  9495 non-null    object
#  14  fielder           6784 non-null    object
#  15  extras_type       10233 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
df1['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Delhi Capitals'], dtype=object)

# %%
#repalcing the obsereved discrepency repeated value
df1.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace = True)

# %%
#let's see how many of total balls are taken wickets
df1['is_wicket'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
len(df1[df1['is_wicket'] == 1])
# Out:
# 9495

# %%
#no extra run scored for the ball played
len(df1[df1['extra_runs'] == 0])
# Out:
# 183235

# %%
df1['dismissal_kind'].fillna('NA', inplace = True)
df1['player_dismissed'].fillna('NA', inplace = True)
df1['fielder'].fillna('NA', inplace = True)
df1['extras_type'].fillna('NA', inplace = True)

# %%
df1.isnull().sum()
# Out:
# id                    0
# inning                0
# over                  0
# ball                  0
# batsman               0
# non_striker           0
# bowler                0
# batsman_runs          0
# extra_runs            0
# total_runs            0
# non_boundary          0
# is_wicket             0
# dismissal_kind        0
# player_dismissed      0
# fielder               0
# extras_type           0
# batting_team          0
# bowling_team        191
# dtype: int64

# %%
df1[df1['bowling_team'].isnull()]
# Out:
#             id  inning  over  ball         batsman     non_striker  \
# 57048   501265       1     0     1         NV Ojha       DA Warner
# 57049   501265       1     0     2       DA Warner         NV Ojha
# 57050   501265       1     1     1       DA Warner         NV Ojha
# 57051   501265       1     1     2         NV Ojha       DA Warner
# 57052   501265       1     1     3         NV Ojha       DA Warner
# ...        ...     ...   ...   ...             ...             ...
# 115654  829763       1     7     3  AB de Villiers   Mandeep Singh
# 115655  829763       1     8     6  AB de Villiers   Mandeep Singh
# 115656  829763       1     9     1   Mandeep Singh  AB de Villiers
# 115657  829763       1     8     4  AB de Villiers   Mandeep Singh
# 115658  829763       1     8     5  AB de Villiers   Mandeep Singh
#
#              bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 57048     AC Thomas             1           0           1             0
# ...

# %%
#merge our data sets
df2 = df.merge(df1, on='id')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193096 entries, 0 to 193095
# Data columns (total 38 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193096 non-null  int64
#  1   city              193096 non-null  object
#  2   date              193096 non-null  datetime64[ns]
#  3   player_of_match   193096 non-null  object
#  4   venue             193096 non-null  object
#  5   neutral_venue     193096 non-null  int64
#  6   team1             193096 non-null  object
#  7   team2             193096 non-null  object
#  8   toss_winner       193096 non-null  object
#  9   toss_decision     193096 non-null  object
#  10  winner            193096 non-null  object
#  11  result            193096 non-null  object
#  12  result_margin     193096 non-null  float64
#  13  eliminator        193096 non-null  object
#  14  method            193096 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
df2.head()
# Out:
#        id       city       date player_of_match                  venue  \
# 0  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 1  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 2  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 3  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 4  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
#
#    neutral_venue                        team1                  team2  \
# 0              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 2              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 3              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 4              0  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# ...

# %%
df2.shape
# Out:
# (193096, 38)

# %%
len(df1) - len(df2)
# Out:
# 372

# %%
len(df2['id'].unique()) == len(df1['id'].unique())
# Out:
# False

# %%
#say because of some ids are not presented in both dataset as when we merged those two dataset, resulted as a decresed of 372
# information. So we can easily say those 191 rows we may encounter in our ball by ball dataset maybe faulty and after merging
# this two dataset we had a clear final data

# %%
df2.isnull().sum()
# Out:
# id                  0
# city                0
# date                0
# player_of_match     0
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              0
# result              0
# result_margin       0
# eliminator          0
# method              0
# umpire1             0
# umpire2             0
# year                0
# month               0
# day                 0
# weekday             0
# inning              0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# non_boundary        0
# is_wicket           0
# dismissal_kind      0
# player_dismissed    0
# fielder             0
# extras_type         0
# batting_team        0
# bowling_team        0
# dtype: int64
